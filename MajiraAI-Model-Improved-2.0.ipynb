# %% [markdown]
# # 🌦️ Majira AI: 7-Day Weather Forecast with LSTM
# This notebook uses LSTM to forecast temperature and rainfall for the next 7 days using 30 days of historical data.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras import Input

# %%
df = pd.read_csv("Nairobi 2023-2025.csv")
df['datetime'] = pd.to_datetime(df['datetime'])
df.set_index('datetime', inplace=True)
df = df.sort_index()
df.head()
# Out:
#             tempmax  tempmin  temp   dew  humidity  precip  windspeed  \
# datetime
# 2023-01-01     26.0     14.8  20.1  10.6      56.7     0.0       36.2
# 2023-01-02     23.0     14.8  18.5  11.8      66.2     0.0       36.5
# 2023-01-03     22.1     16.0  18.5  14.0      76.1     0.0       38.3
# 2023-01-04     21.1     16.0  17.9  14.2      80.1     0.0       27.7
# 2023-01-05     24.0     14.9  18.6  11.3      65.5     0.0       31.7
#
#             windspeedmax  windspeedmin  winddir  sealevelpressure  cloudcover  \
# datetime
# 2023-01-01          36.2           0.5     75.5            1022.6        51.6
# 2023-01-02          36.5           1.3     75.5            1022.2        66.4
# 2023-01-03          38.3           1.7     73.0            1022.5        75.1
# 2023-01-04          27.7           1.1     68.3            1022.4        83.6
# 2023-01-05          31.7           1.1     54.1            1022.0        70.8
#
#             visibility
# datetime
# 2023-01-01        10.3
# 2023-01-02        10.3
# 2023-01-03        10.0
# 2023-01-04        10.1
# 2023-01-05        10.1

# %%
data = df[['temp', 'precip']].copy()
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(data)

# %%
def create_7_day_sequences(data, input_window=30, forecast_horizon=7):
    X, y = [], []
    for i in range(len(data) - input_window - forecast_horizon + 1):
        X.append(data[i:i+input_window])
        y.append(data[i+input_window:i+input_window+forecast_horizon])
    return np.array(X), np.array(y)

X, y = create_7_day_sequences(scaled_data)
X.shape, y.shape
# Out:
# ((786, 30, 2), (786, 7, 2))

# %%
split = int(0.8 * len(X))
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]
X_train.shape, y_train.shape
# Out:
# ((628, 30, 2), (628, 7, 2))

# %%
model = Sequential()
model.add(LSTM(64, activation='relu', return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dropout(0.2))
model.add(LSTM(64, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(7 * 2))  # 7 days * 2 features
model.compile(optimizer='adam', loss='mse')
model.summary()
# Out:
# C:\Users\PC\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 30, 64)              │          17,152 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 30, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 64)                  │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 14)                  │             910 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 51,086 (199.55 KB)
#  Trainable params: 51,086 (199.55 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
y_train_flat = y_train.reshape((y_train.shape[0], y_train.shape[1] * y_train.shape[2]))
y_test_flat = y_test.reshape((y_test.shape[0], y_test.shape[1] * y_test.shape[2]))

# %%
history = model.fit(X_train, y_train_flat, epochs=50, batch_size=32, validation_split=0.1)
# Out:
# Epoch 1/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - loss: 0.1402 - val_loss: 0.0371
# Epoch 2/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0502 - val_loss: 0.0102
# Epoch 3/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0240 - val_loss: 0.0113
# Epoch 4/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0202 - val_loss: 0.0101
# Epoch 5/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0209 - val_loss: 0.0105
# Epoch 6/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0204 - val_loss: 0.0084
# Epoch 7/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0180 - val_loss: 0.0093
# Epoch 8/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0179 - val_loss: 0.0086
# Epoch 9/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0169 - val_loss: 0.0109
# Epoch 10/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0174 - val_loss: 0.0086
# Epoch 11/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0166 - val_loss: 0.0082
# Epoch 12/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0162 - val_loss: 0.0088
# Epoch 13/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0165 - val_loss: 0.0094
# Epoch 14/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0164 - val_loss: 0.0092
# Epoch 15/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0150 - val_loss: 0.0110
# Epoch 16/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0159 - val_loss: 0.0089
# Epoch 17/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0156 - val_loss: 0.0076
# Epoch 18/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0155 - val_loss: 0.0097
# Epoch 19/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0153 - val_loss: 0.0082
# Epoch 20/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0155 - val_loss: 0.0085
# Epoch 21/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0154 - val_loss: 0.0078
# Epoch 22/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0146 - val_loss: 0.0092
# Epoch 23/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0144 - val_loss: 0.0082
# Epoch 24/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0145 - val_loss: 0.0084
# Epoch 25/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0148 - val_loss: 0.0088
# Epoch 26/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0158 - val_loss: 0.0091
# Epoch 27/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0151 - val_loss: 0.0084
# Epoch 28/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0140 - val_loss: 0.0105
# Epoch 29/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0134 - val_loss: 0.0085
# Epoch 30/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0144 - val_loss: 0.0100
# Epoch 31/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0150 - val_loss: 0.0097
# Epoch 32/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0140 - val_loss: 0.0088
# Epoch 33/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0133 - val_loss: 0.0083
# Epoch 34/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0137 - val_loss: 0.0086
# Epoch 35/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0130 - val_loss: 0.0081
# Epoch 36/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0143 - val_loss: 0.0121
# Epoch 37/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0133 - val_loss: 0.0086
# Epoch 38/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0138 - val_loss: 0.0080
# Epoch 39/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0136 - val_loss: 0.0095
# Epoch 40/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0141 - val_loss: 0.0082
# Epoch 41/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0139 - val_loss: 0.0093
# Epoch 42/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0128 - val_loss: 0.0103
# Epoch 43/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0139 - val_loss: 0.0084
# Epoch 44/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0130 - val_loss: 0.0083
# Epoch 45/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0123 - val_loss: 0.0080
# Epoch 46/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0135 - val_loss: 0.0082
# Epoch 47/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0127 - val_loss: 0.0086
# Epoch 48/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0127 - val_loss: 0.0082
# Epoch 49/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0128 - val_loss: 0.0087
# Epoch 50/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0126 - val_loss: 0.0086

# %%
predictions = model.predict(X_test)
predictions = predictions.reshape((-1, 7, 2))
predicted_values = scaler.inverse_transform(predictions.reshape(-1, 2))
actual_values = scaler.inverse_transform(y_test.reshape(-1, 2))
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step

# %%
plt.figure(figsize=(12, 5))
plt.plot(actual_values[:100, 0], label='Actual Temp')
plt.plot(predicted_values[:100, 0], label='Predicted Temp')
plt.title("Temperature Forecast (First 100 points)")
plt.legend()
plt.show()

plt.figure(figsize=(12, 5))
plt.plot(actual_values[:100, 1], label='Actual Rainfall')
plt.plot(predicted_values[:100, 1], label='Predicted Rainfall')
plt.title("Rainfall Forecast (First 100 points)")
plt.legend()
plt.show()

# %% [markdown]
# ## 📅 Weekly Average Forecast: Temperature & Rainfall
# This section predicts the average temperature and rainfall over the next 7 days using the past 30 days as input.

# %%
def create_weekly_avg_targets(data, input_window=30, forecast_horizon=7):
    X, y = [], []
    for i in range(len(data) - input_window - forecast_horizon + 1):
        X.append(data[i:i+input_window])
        next_week = data[i+input_window:i+input_window+forecast_horizon]
        weekly_avg = np.mean(next_week, axis=0)  # avg temp & precip
        y.append(weekly_avg)
    return np.array(X), np.array(y)

X_weekly, y_weekly = create_weekly_avg_targets(scaled_data)
split = int(0.8 * len(X_weekly))
X_train_w, X_test_w = X_weekly[:split], X_weekly[split:]
y_train_w, y_test_w = y_weekly[:split], y_weekly[split:]
X_train_w.shape, y_train_w.shape
# Out:
# ((628, 30, 2), (628, 2))

# %%
model_weekly = Sequential()
model_weekly.add(LSTM(64, activation='relu', input_shape=(X_train_w.shape[1], X_train_w.shape[2])))
model_weekly.add(Dropout(0.2))
model_weekly.add(Dense(2))  # 1 avg temp + 1 avg precip
model_weekly.compile(optimizer='adam', loss='mse')
model_weekly.summary()
# Out:
# C:\Users\PC\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_2 (LSTM)                        │ (None, 64)                  │          17,152 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 2)                   │             130 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 17,282 (67.51 KB)
#  Trainable params: 17,282 (67.51 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history_weekly = model_weekly.fit(X_train_w, y_train_w, epochs=50, batch_size=32, validation_split=0.1)
# Out:
# Epoch 1/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 0.1368 - val_loss: 0.0297
# Epoch 2/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0298 - val_loss: 0.0038
# Epoch 3/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0119 - val_loss: 0.0028
# Epoch 4/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0089 - val_loss: 0.0032
# Epoch 5/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0088 - val_loss: 0.0031
# Epoch 6/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0095 - val_loss: 0.0044
# Epoch 7/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0088 - val_loss: 0.0031
# Epoch 8/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0073 - val_loss: 0.0040
# Epoch 9/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0087 - val_loss: 0.0032
# Epoch 10/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0084 - val_loss: 0.0056
# Epoch 11/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0087 - val_loss: 0.0040
# Epoch 12/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0084 - val_loss: 0.0041
# Epoch 13/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0077 - val_loss: 0.0043
# Epoch 14/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0080 - val_loss: 0.0037
# Epoch 15/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0075 - val_loss: 0.0042
# Epoch 16/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0076 - val_loss: 0.0029
# Epoch 17/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0084 - val_loss: 0.0030
# Epoch 18/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0078 - val_loss: 0.0045
# Epoch 19/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0083 - val_loss: 0.0036
# Epoch 20/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0072 - val_loss: 0.0033
# Epoch 21/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0074 - val_loss: 0.0032
# Epoch 22/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0076 - val_loss: 0.0036
# Epoch 23/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0074 - val_loss: 0.0037
# Epoch 24/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0073 - val_loss: 0.0040
# Epoch 25/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0070 - val_loss: 0.0045
# Epoch 26/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0070 - val_loss: 0.0045
# Epoch 27/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0064 - val_loss: 0.0040
# Epoch 28/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0074 - val_loss: 0.0034
# Epoch 29/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0073 - val_loss: 0.0034
# Epoch 30/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0069 - val_loss: 0.0038
# Epoch 31/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0076 - val_loss: 0.0041
# Epoch 32/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0068 - val_loss: 0.0038
# Epoch 33/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0071 - val_loss: 0.0029
# Epoch 34/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0066 - val_loss: 0.0044
# Epoch 35/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0071 - val_loss: 0.0040
# Epoch 36/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0063 - val_loss: 0.0043
# Epoch 37/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0065 - val_loss: 0.0046
# Epoch 38/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0067 - val_loss: 0.0037
# Epoch 39/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0066 - val_loss: 0.0039
# Epoch 40/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0066 - val_loss: 0.0032
# Epoch 41/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0067 - val_loss: 0.0045
# Epoch 42/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0064 - val_loss: 0.0042
# Epoch 43/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0061 - val_loss: 0.0040
# Epoch 44/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0071 - val_loss: 0.0039
# Epoch 45/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0060 - val_loss: 0.0034
# Epoch 46/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0062 - val_loss: 0.0041
# Epoch 47/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0061 - val_loss: 0.0049
# Epoch 48/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0062 - val_loss: 0.0044
# Epoch 49/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0058 - val_loss: 0.0042
# Epoch 50/50
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0065 - val_loss: 0.0032

# %%
# Predict weekly averages
pred_weekly = model_weekly.predict(X_test_w)

# Pad with dummy zeros to match original 2-feature shape if needed
def pad_for_inverse_transform(data, feature_count=2):
    if data.shape[1] == feature_count:
        return data
    padded = np.zeros((data.shape[0], feature_count))
    padded[:, :data.shape[1]] = data
    return padded

# Apply fix for inverse_transform
pred_weekly_padded = pad_for_inverse_transform(pred_weekly)
y_test_weekly_padded = pad_for_inverse_transform(y_test_w)

# Inverse transform
pred_weekly_inverse = scaler.inverse_transform(pred_weekly_padded)
actual_weekly_inverse = scaler.inverse_transform(y_test_weekly_padded)

# Plot weekly average temperature
plt.figure(figsize=(12, 5))
plt.plot(actual_weekly_inverse[:100, 0], label='Actual Avg Temp')
plt.plot(pred_weekly_inverse[:100, 0], label='Predicted Avg Temp')
plt.title("Weekly Avg Temperature Forecast")
plt.legend()
plt.show()

# Plot weekly average rainfall
plt.figure(figsize=(12, 5))
plt.plot(actual_weekly_inverse[:100, 1], label='Actual Avg Rainfall')
plt.plot(pred_weekly_inverse[:100, 1], label='Predicted Avg Rainfall')
plt.title("Weekly Avg Rainfall Forecast")
plt.legend()
plt.show()
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step

# %% [markdown]
# ## 🚀 Improved 7-Day Forecast Model
# This section improves the earlier model using Bidirectional LSTM, Huber loss, and more epochs for better trend and fluctuation learning.

# %%
from tensorflow.keras import Input
from tensorflow.keras.layers import Bidirectional
from tensorflow.keras.losses import Huber

model_improved = Sequential()
model_improved.add(Input(shape=(X_train.shape[1], X_train.shape[2])))
model_improved.add(Bidirectional(LSTM(64, activation='relu', return_sequences=True)))
model_improved.add(Dropout(0.2))
model_improved.add(Bidirectional(LSTM(64, activation='relu')))
model_improved.add(Dropout(0.2))
model_improved.add(Dense(7 * 2))  # 7 days * 2 features
model_improved.compile(optimizer='adam', loss=Huber())
model_improved.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ bidirectional (Bidirectional)        │ (None, 30, 128)             │          34,304 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 30, 128)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_1 (Bidirectional)      │ (None, 128)                 │          98,816 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 14)                  │           1,806 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 134,926 (527.05 KB)
#  Trainable params: 134,926 (527.05 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
y_train_flat = y_train.reshape((y_train.shape[0], y_train.shape[1] * y_train.shape[2]))
y_test_flat = y_test.reshape((y_test.shape[0], y_test.shape[1] * y_test.shape[2]))

# %%
history_improved = model_improved.fit(X_train, y_train_flat, epochs=100, batch_size=32, validation_split=0.1)
# Out:
# Epoch 1/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 11s 108ms/step - loss: 0.0614 - val_loss: 0.0060
# Epoch 2/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0119 - val_loss: 0.0047
# Epoch 3/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0099 - val_loss: 0.0049
# Epoch 4/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0094 - val_loss: 0.0048
# Epoch 5/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0087 - val_loss: 0.0046
# Epoch 6/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0091 - val_loss: 0.0056
# Epoch 7/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.0082 - val_loss: 0.0047
# Epoch 8/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0089 - val_loss: 0.0044
# Epoch 9/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0078 - val_loss: 0.0048
# Epoch 10/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0075 - val_loss: 0.0044
# Epoch 11/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0077 - val_loss: 0.0051
# Epoch 12/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0072 - val_loss: 0.0050
# Epoch 13/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0077 - val_loss: 0.0054
# Epoch 14/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0072 - val_loss: 0.0039
# Epoch 15/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0077 - val_loss: 0.0041
# Epoch 16/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0079 - val_loss: 0.0039
# Epoch 17/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - loss: 0.0075 - val_loss: 0.0048
# Epoch 18/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0071 - val_loss: 0.0044
# Epoch 19/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0074 - val_loss: 0.0047
# Epoch 20/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0069 - val_loss: 0.0044
# Epoch 21/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0074 - val_loss: 0.0043
# Epoch 22/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0067 - val_loss: 0.0044
# Epoch 23/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0065 - val_loss: 0.0050
# Epoch 24/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 0.0059 - val_loss: 0.0039
# Epoch 25/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0069 - val_loss: 0.0039
# Epoch 26/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 0.0063 - val_loss: 0.0040
# Epoch 27/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0065 - val_loss: 0.0043
# Epoch 28/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0063 - val_loss: 0.0041
# Epoch 29/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0066 - val_loss: 0.0047
# Epoch 30/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0063 - val_loss: 0.0047
# Epoch 31/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0062 - val_loss: 0.0040
# Epoch 32/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0063 - val_loss: 0.0043
# Epoch 33/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0065 - val_loss: 0.0039
# Epoch 34/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0063 - val_loss: 0.0043
# Epoch 35/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0058 - val_loss: 0.0042
# Epoch 36/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0063 - val_loss: 0.0042
# Epoch 37/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0059 - val_loss: 0.0040
# Epoch 38/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.0060 - val_loss: 0.0040
# Epoch 39/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0058 - val_loss: 0.0044
# Epoch 40/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0056 - val_loss: 0.0042
# Epoch 41/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0060 - val_loss: 0.0052
# Epoch 42/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0055 - val_loss: 0.0040
# Epoch 43/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0056 - val_loss: 0.0048
# Epoch 44/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0060 - val_loss: 0.0039
# Epoch 45/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0058 - val_loss: 0.0045
# Epoch 46/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - loss: 0.0051 - val_loss: 0.0038
# Epoch 47/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.0057 - val_loss: 0.0040
# Epoch 48/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0056 - val_loss: 0.0042
# Epoch 49/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0053 - val_loss: 0.0043
# Epoch 50/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.0055 - val_loss: 0.0043
# Epoch 51/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0057 - val_loss: 0.0053
# Epoch 52/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0055 - val_loss: 0.0040
# Epoch 53/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0057 - val_loss: 0.0046
# Epoch 54/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0053 - val_loss: 0.0043
# Epoch 55/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0051 - val_loss: 0.0043
# Epoch 56/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0052 - val_loss: 0.0047
# Epoch 57/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0056 - val_loss: 0.0048
# Epoch 58/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0053 - val_loss: 0.0045
# Epoch 59/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0052 - val_loss: 0.0042
# Epoch 60/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0051 - val_loss: 0.0043
# Epoch 61/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 0.0053 - val_loss: 0.0049
# Epoch 62/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0052 - val_loss: 0.0047
# Epoch 63/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0058 - val_loss: 0.0045
# Epoch 64/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0047 - val_loss: 0.0045
# Epoch 65/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0051 - val_loss: 0.0048
# Epoch 66/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0049 - val_loss: 0.0047
# Epoch 67/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 0.0049 - val_loss: 0.0042
# Epoch 68/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 0.0052 - val_loss: 0.0046
# Epoch 69/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0046 - val_loss: 0.0044
# Epoch 70/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0045 - val_loss: 0.0045
# Epoch 71/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0051 - val_loss: 0.0047
# Epoch 72/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0048 - val_loss: 0.0047
# Epoch 73/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.0047 - val_loss: 0.0054
# Epoch 74/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0047 - val_loss: 0.0046
# Epoch 75/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0051 - val_loss: 0.0047
# Epoch 76/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 0.0048 - val_loss: 0.0048
# Epoch 77/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0046 - val_loss: 0.0043
# Epoch 78/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0045 - val_loss: 0.0047
# Epoch 79/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0045 - val_loss: 0.0045
# Epoch 80/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0046 - val_loss: 0.0049
# Epoch 81/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0044 - val_loss: 0.0053
# Epoch 82/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0046 - val_loss: 0.0044
# Epoch 83/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0051 - val_loss: 0.0046
# Epoch 84/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 0.0050 - val_loss: 0.0050
# Epoch 85/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0047 - val_loss: 0.0053
# Epoch 86/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 0.0044 - val_loss: 0.0053
# Epoch 87/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0045 - val_loss: 0.0048
# Epoch 88/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0043 - val_loss: 0.0052
# Epoch 89/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.0044 - val_loss: 0.0052
# Epoch 90/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0043 - val_loss: 0.0049
# Epoch 91/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.0046 - val_loss: 0.0053
# Epoch 92/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0043 - val_loss: 0.0049
# Epoch 93/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0046 - val_loss: 0.0051
# Epoch 94/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0040 - val_loss: 0.0051
# Epoch 95/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.0040 - val_loss: 0.0054
# Epoch 96/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0043 - val_loss: 0.0049
# Epoch 97/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - loss: 0.0041 - val_loss: 0.0046
# Epoch 98/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0042 - val_loss: 0.0049
# Epoch 99/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.0045 - val_loss: 0.0050
# Epoch 100/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - loss: 0.0041 - val_loss: 0.0047

# %%
pred_improved = model_improved.predict(X_test)
pred_improved = pred_improved.reshape((-1, 7, 2))
predicted_values_improved = scaler.inverse_transform(pred_improved.reshape(-1, 2))
actual_values_improved = scaler.inverse_transform(y_test.reshape(-1, 2))
# Out:
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000002B1F01D7380> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000002B1F01D7380> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 298ms/step

# %%
plt.figure(figsize=(12, 5))
plt.plot(actual_values_improved[:100, 0], label='Actual Temp')
plt.plot(predicted_values_improved[:100, 0], label='Predicted Temp (Improved)')
plt.title("Temperature Forecast - Improved Model (First 100 points)")
plt.legend()
plt.show()

plt.figure(figsize=(12, 5))
plt.plot(actual_values_improved[:100, 1], label='Actual Rainfall')
plt.plot(predicted_values_improved[:100, 1], label='Predicted Rainfall (Improved)')
plt.title("Rainfall Forecast - Improved Model (First 100 points)")
plt.legend()
plt.show()

# %% [markdown]
# ## 📏 Model Evaluation Metrics (RMSE, MAE, R²)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

# Flatten true and predicted values
y_true = y_test.reshape(-1, 2)
y_pred = pred_improved.reshape(-1, 2)

# Metrics
rmse = np.sqrt(mean_squared_error(y_true, y_pred))
mae = mean_absolute_error(y_true, y_pred)
r2 = r2_score(y_true, y_pred)

print(f"RMSE: {rmse:.4f}")
print(f"MAE: {mae:.4f}")
print(f"R² Score: {r2:.4f}")
# Out:
# RMSE: 0.1130
# MAE: 0.0731
# R² Score: -0.1162

# %% [markdown]
# ## 📈 Refined Visualization with Overlayed Predictions

# %%
import matplotlib.pyplot as plt

labels = ['Temperature', 'Rainfall']
for i in range(2):
    plt.figure(figsize=(12, 5))
    plt.plot(actual_values_improved[:100, i], label=f"Actual {labels[i]}", linewidth=2)
    plt.plot(predicted_values_improved[:100, i], label=f"Predicted {labels[i]}", linewidth=2)
    plt.title(f"Overlayed Forecast vs Actual: {labels[i]}")
    plt.xlabel("Time Steps")
    plt.ylabel(labels[i])
    plt.legend()
    plt.grid(True)
    plt.show()
